# %%
#1. Program to write explain  different types of Inheritances using classes.
# Single Inheritance
class Parent:
  def show_parent(self):
    print("This is Parent class")
class Child(Parent):
  def show_child(self):
    print("This is Child class")

obj = Child()
obj.show_parent()
obj.show_child()


# Multilevel Inheritance
class Grandparent:
    def house(self):
        print("Grandparent's House")

class Parent2(Grandparent):
    def car(self):
        print("Parent's Car")

class Child2(Parent2):
    def bike(self):
        print("Child's Bike")

obj2 = Child2()
obj2.house()
obj2.car()
obj2.bike()


# Multiple Inheritance
class Father:
    def skills1(self):
        print("Driving")

class Mother:
    def skills2(self):
        print("Cooking")

class Child3(Father, Mother):
    pass

obj3 = Child3()
obj3.skills1()
obj3.skills2()


# Hierarchical Inheritance
class Animal:
    def eat(self):
        print("Animal eats food")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

class Cat(Animal):
    def meow(self):
        print("Cat meows")

d = Dog()
c = Cat()

d.eat()
d.bark()

c.eat()
c.meow()


# Hybrid Inheritance
class A:
    def methodA(self):
        print("Class A")

class B(A):
    def methodB(self):
        print("Class B")

class C(A):
    def methodC(self):
        print("Class C")

class D(B, C):
    def methodD(self):
      print("Class D")
obj4 = D()
obj4.methodA()
obj4.methodB()
obj4.methodC()
obj4.methodD()
# Out:
# This is Parent class
# This is Child class
# Grandparent's House
# Parent's Car
# Child's Bike
# Driving
# Cooking
# Animal eats food
# Dog barks
# Animal eats food
# Cat meows
# Class A
# Class B
# Class C
# Class D

# %%
#2. Write a python program to create a class called Employee with methods called work() and getSalary().
class Employee:
  def work(self):
    print("Employee is working")
  def getSalary(self):
    print("Salary is 50000")

emp = Employee()
emp.work()
emp.getSalary()
# Out:
# Employee is working
# Salary is 50000

# %%
#3. Create a subclass called HRManager that overrides the work() method and adds a new method called addEmployee().
class Employee:

    def work(self):
        print("Employee is working")

class HRManager(Employee):

    def work(self):
        print("HR Manager manages employees")

    def addEmployee(self):
        print("New employee added")


hr = HRManager()

hr.work()
hr.addEmployee()
# Out:
# HR Manager manages employees
# New employee added

# %%
#4. Program to Show Polymorphism in Class
class Bird:
  def sound(self):
    print("Bird makes sound")
class Sparrow(Bird):
  def sound(self):
    print("Sparrow chirps")
class Crow(Bird):
  def sound(self):
    print("Crow caws")
b1 = Bird()
b2 = Crow()
b1.sound()
b2.sound()
# Out:
# Bird makes sound
# Crow caws

# %%
#5. Program to Show Overloading of Methods in Class
class Calculator:
  def add(self, a, b=0, c=0):
    print("Sum =", a + b + c)
obj = Calculator()
obj.add(10)
obj.add(10, 20)
obj.add(10, 20, 30)
# Out:
# Sum = 10
# Sum = 30
# Sum = 60

# %%
#6. Program to Show Overriding of Methods in Classes
class Animal:
  def sound(self):
    print("Animal makes sound")
class Dog(Animal):
  def sound(self):
    print("Dog barks")
class Cat(Animal):
  def sound(self):
    print("Cat meows")
obj = Dog()
obj.sound()
# Out:
# Dog barks

# %%
#7. Write a Java program to create a class known as Person with methods called getFirstName() and getLastName().
class Person:
  def getFirstName(self):
    return "Jassmitha"
  def getLastName(self):
    return "Reddy"
p = Person()
print(p.getFirstName())
print(p.getLastName())
# Out:
# Jassmitha
# Reddy

# %%
#8. Create a subclass called Employee that adds a new method named getEmployeeId() and overrides the getLastName() method to include the employee's job title.
class Person:

    def getFirstName(self):
        return "Jassmitha"

    def getLastName(self):
        return "Reddy"

class Employee(Person):

    def getEmployeeId(self):
        return 101

    def getLastName(self):
        return "Reddy - AI Engineer"


emp = Employee()

print(emp.getFirstName())
print(emp.getLastName())
print(emp.getEmployeeId())
# Out:
# Jassmitha
# Reddy - AI Engineer
# 101

# %%
#9. Program to Show Abstraction in Class
from abc import ABC, abstractmethod
class Vehicle(ABC):
  @abstractmethod
  def start(self):
    pass
class Car(Vehicle):
  def start(self):
    print("Car starts with key")
obj = Car()
obj.start()
# Out:
# Car starts with key

# %%
#11. Write a python program that creates a class hierarchy for employees of a company. The base class should be Employee, with subclasses Manager, Developer, and Programmer. Each subclass should have properties such as name, address, salary, and job title.Implement methods for calculating bonuses, generating performance reports, and managing projects.
class Employee:

    def __init__(self, name, address, salary, job_title):
        self.name = name
        self.address = address
        self.salary = salary
        self.job_title = job_title

    def calculate_bonus(self):
        return self.salary * 0.10

    def performance_report(self):
      print(self.name, "has excellent performance")

    def manage_project(self):
      print(self.name, "is managing project")

class Manager(Employee):
  pass
class Developer(Employee):
  pass
class Programmer(Employee):
  pass

m = Manager("Ravi", "Hyderabad", 80000, "Manager")
print("Bonus =", m.calculate_bonus())

m.performance_report()
m.manage_project()
# Out:
# Bonus = 8000.0
# Ravi has excellent performance
# Ravi is managing project

# %%
#12. Write a program to explain Dynamic Binding.
class Animal:

    def sound(self):
        print("Animal sound")

class Dog(Animal):

    def sound(self):
        print("Dog barks")

obj = Dog()
obj.sound()
# Out:
# Dog barks

# %%
#13. Program to Show Use of Super Keyword in Class
class Parent:

    def show(self):
        print("Parent method")

class Child(Parent):

    def show(self):
        super().show()
        print("Child method")

obj = Child()
obj.show()
# Out:
# Parent method
# Child method

# %%
#16. Program to Show Usage of Access Modifier
class Student:
  public_var = "Public"
  _protected_var = "Protected"
  __private_var = "Private"
obj = Student()
print(obj.public_var)
print(obj._protected_var)
# print(obj.__private_var)  # Error
# Out:
# Public
# Protected
