# %%
#1. Write a program to print the sum of elements in a List.
numbers = [10, 20, 30, 40]

total = sum(numbers)

print("Sum =", total)
# Out:
# Sum = 100

# %%
#2. Write a program to get the Largest Number in the List.
numbers = [10, 40, 20, 80, 50]

largest = max(numbers)

print("Largest =", largest)
# Out:
# Largest = 80

# %%
#3. Remove Common Elements from two Lists.
list1 = [1,2,3,4]
list2 = [3,4,5,6]

common = set(list1) & set(list2)

result1 = [x for x in list1 if x not in common]
result2 = [x for x in list2 if x not in common]

print(result1)
print(result2)
# Out:
# [1, 2]
# [5, 6]

# %%
#4. Write a Python program to find the second-smallest number in a List.
numbers = [8, 4, 2, 9, 5]

numbers.sort()

print("Second Smallest =", numbers[1])
# Out:
# Second Smallest = 4

# %%
#5. Write a Python program to find elements in a given set that are not in another set.
set1 = {1,2,3,4,5}
set2 = {3,4,5}

result = set1 - set2

print(result)
# Out:
# {1, 2}

# %%
#6. Given two sets of numbers, write a Python program to find the missing numbers in the second set as compared to the first and vice versa.
set1 = {1,2,3,4,5}
set2 = {2,3,6}

print("Missing in Set2:", set1 - set2)
print("Missing in Set1:", set2 - set1)
# Out:
# Missing in Set2: {1, 4, 5}
# Missing in Set1: {6}

# %%
#7. Write a Python program that finds all pairs of elements in a list whose sum is equal to a given value.
numbers = [1,2,3,4,5]
target = 6

for i in range(len(numbers)):
    for j in range(i+1,len(numbers)):
        if numbers[i] + numbers[j] == target:
            print(numbers[i], numbers[j])
# Out:
# 1 5
# 2 4

# %%
#8. Write a Python program to find the two numbers whose product is maximum among all the pairs in a given list of numbers and use the Python set.
numbers = [2,7,4,9,5]

numbers.sort()

print("Pair:", numbers[-1], numbers[-2])
print("Product:", numbers[-1]*numbers[-2])
# Out:
# Pair: 9 7
# Product: 63

# %%
#9. Write a Python program to find the maximum and minimum values in a set.
s = {10,30,50,20}

print("Maximum =", max(s))
print("Minimum =", min(s))
# Out:
# Maximum = 50
# Minimum = 10

# %%
#10. Write a Python program to remove an item from a set if it is present in the set.
s = {10,20,30}

s.discard(20)

print(s)
# Out:
# {10, 30}

# %%
#11. Write a Python program to create a tuple with different data types.
data = (10, "Python", 3.14, True)

print(data)
# Out:
# (10, 'Python', 3.14, True)

# %%
#12. Write a Python program to unpack a tuple into several variables.
t = (10,20,30)

a,b,c = t

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
#13. Write a Python program to find repeated items in a tuple.
t = (1,2,3,2,4,1,5)

repeated = set()

for item in t:
    if t.count(item) > 1:
        repeated.add(item)

print(repeated)
# Out:
# {1, 2}

# %%
#14. Write a Python program to reverse a tuple.
t = (10,20,30,40)

reversed_tuple = t[::-1]

print(reversed_tuple)
# Out:
# (40, 30, 20, 10)

# %%
#15. Write a Python program to replace the last value of the tuples in a list [(10, 20, 40), (40, 50, 60), (70, 80, 90)] Expected Output: [(10, 20, 100), (40, 50, 100), (70, 80, 100)].
data = [(10,20,40),(40,50,60),(70,80,90)]

result = [t[:-1] + (100,) for t in data]

print(result)
# Out:
# [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
#16. Write a Python program to convert a given tuple of positive integers into an integer,  Original tuple: (1, 2, 3)   Expected output: 123
t = (1,2,3)

number = int(''.join(map(str,t)))

print(number)
# Out:
# 123

# %%
#17. Write a Python program to compute the sum of all the elements of each tuple stored inside a list of tuples,  Original list of tuples: [(1, 2), (2, 3), (3, 4)]  Sum of all the elements of each tuple [3, 5, 7]
data = [(1,2),(2,3),(3,4)]

result = [sum(t) for t in data]

print(result)
# Out:
# [3, 5, 7]

# %%
#18. Write a Python script to print a dictionary where the keys are numbers between 1 and 10 (both included) and the values are the square of the keys. Sample Dictionary {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}.
squares = {x:x*x for x in range(1,11)}

print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
#19. Write a Python program to combine two dictionary by adding values for,
# common keys.d1 = {'a': 100, 'b': 200, 'c':300} d2 = {'a': 300, 'b': 200, 'd':400}
# Sample output: Counter ({'a': 400, 'b': 400, 'd': 400, 'c': 300})
from collections import Counter

d1 = {'a':100,'b':200,'c':300}
d2 = {'a':300,'b':200,'d':400}

result = Counter(d1) + Counter(d2)

print(result)
# Out:
# Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %%
#20. Write a Python program to convert more than one list to a nested dictionary,
# Original strings: ['S001', 'S002', 'S003', 'S004'] ['Adina Park', 'Leyton Marsh', 'Duncan Boyle', 'Saim Richards'] [85, 98, 89, 92]
# Nested dictionary: [{'S001': {'Adina Park': 85}}, {'S002': {'Leyton Marsh': 98}}, {'S003': {'Duncan Boyle': 89}}, {'S004': {'Saim Richards': 92}}]
ids = ['S001','S002','S003','S004']

names = ['Adina Park','Leyton Marsh',
         'Duncan Boyle','Saim Richards']

marks = [85,98,89,92]

result = []

for i in range(len(ids)):
    result.append(
        {ids[i]: {names[i]: marks[i]}}
    )

print(result)
# Out:
# [{'S001': {'Adina Park': 85}}, {'S002': {'Leyton Marsh': 98}}, {'S003': {'Duncan Boyle': 89}}, {'S004': {'Saim Richards': 92}}]

# %%
#21. Write a Python program to convert a dictionary into a list of lists,
# Original Dictionary: {1: 'red', 2: 'green', 3: 'black', 4: 'white', 5: 'black'}
# Convert the said dictionary into a list of lists: [[1, 'red'], [2, 'green'], [3, 'black'], [4, 'white'], [5, 'black']]
d = {
    1:'red',
    2:'green',
    3:'black',
    4:'white',
    5:'black'
}

result = [[k,v] for k,v in d.items()]

print(result)
# Out:
# [[1, 'red'], [2, 'green'], [3, 'black'], [4, 'white'], [5, 'black']]

# %%
#22. Write a Python program to get the key, value and item in a dictionary.
d = {
    "name":"John",
    "age":21
}

print("Keys:", d.keys())

print("Values:", d.values())

print("Items:", d.items())
# Out:
# Keys: dict_keys(['name', 'age'])
# Values: dict_values(['John', 21])
# Items: dict_items([('name', 'John'), ('age', 21)])

# %%
#23. Write a Python program to get the maximum and minimum values of a dictionary.
d = {
    'a':100,
    'b':300,
    'c':50,
    'd':200
}

print("Maximum =", max(d.values()))

print("Minimum =", min(d.values()))
# Out:
# Maximum = 300
# Minimum = 50
